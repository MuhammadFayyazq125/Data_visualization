# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import math

# %%
data = pd.read_excel('excel_data_solution.xlsx', sheet_name = '365RE' , index_col = 0)
data.head()
# Out:
#       Building  Year of sale  Month of sale Type of property  Property #  \
# ID
# 1030         1        2005.0           11.0        Apartment          30
# 1029         1        2005.0           10.0        Apartment          29
# 2002         2        2007.0            7.0        Apartment           2
# 2031         2        2007.0           12.0        Apartment          31
# 1049         1        2004.0           11.0        Apartment          49
#
#       Area (ft.)        Price Status Customer ID      Entity  ...       Y  \
# ID                                                            ...
# 1030    743.0856  246172.6760   Sold       C0028  Individual  ...  1986.0
# 1029    756.2128  246331.9040   Sold       C0027  Individual  ...  1983.0
# 2002    587.2808  209280.9104   Sold       C0112  Individual  ...  1985.0
# 2031   1604.7464  452667.0064   Sold       C0160  Individual  ...  1985.0
# 1049   1375.4508  467083.3132   Sold       C0014  Individual  ...  1979.0
#
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.hist(data['Price'] , bins = 272 , edgecolor = 'green')
plt.show()

# %%
plt.hist(data['Price'] , bins = math.ceil((data['Price'].max() - data['Price'].min())/100000), edgecolor = 'black')
plt.show()

# %% [markdown]
# # Task 4

# %%
intervale = [217564.07, 317564.07]
for i in intervale:
    new_i=math.ceil((data['Price'].max() - data['Price'].min())/i)
plt.hist(data['Price'], bins =new_i, edgecolor = 'red')
plt.show()

# %%
# task 5
plt.scatter(data['Price'], data['Area (ft.)'] , alpha = 1)
plt.show()

# %%
# task 6

# %%
import matplotlib.ticker as mtick

# %%
# data['Frequency_new1'] = data['Country'].value_counts()
# data['Relative_Frequency'] = data['Frequency']/data['Frequency'].sum()*100
# data['Commulative_Frequency'] = data['Relative_Frequency'].cumsum()
data
# Out:
#       Building  Year of sale  Month of sale Type of property  Property #  \
# ID
# 1030         1        2005.0           11.0        Apartment          30
# 1029         1        2005.0           10.0        Apartment          29
# 2002         2        2007.0            7.0        Apartment           2
# 2031         2        2007.0           12.0        Apartment          31
# 1049         1        2004.0           11.0        Apartment          49
# ...        ...           ...            ...              ...         ...
# 5044         5           NaN            NaN        Apartment          44
# 5047         5           NaN            NaN        Apartment          47
# 5048         5           NaN            NaN        Apartment          48
# 5050         5           NaN            NaN        Apartment          50
# 5051         5           NaN            NaN        Apartment          51
#
#       Area (ft.)        Price Status Customer ID      Entity  ...       Y  \
# ...

# %%
frequency = data.value_counts(data['Country'],ascending=False).astype('int64')
relative_frequency =(data.value_counts(data['Country'],ascending=False , normalize = True) * 100).astype('int64')
cummulative_frequency = relative_frequency.cumsum().astype('int64')
# frequency
# relative_frequency
# cummulative_frequency
fig, ax = plt.subplots()
ax.bar(['USA', 'Canada','Russia', 'Belgium', 'UK', 'Denmark','Germany', 'Mexico'], frequency, color ="blue")
ax2 = ax.twinx()
ax2.plot(['USA', 'Canada','Russia', 'Belgium', 'UK', 'Denmark','Germany', 'Mexico'],cummulative_frequency, color = "green" , marker="D", ms=7 )
ax2.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.tick_params(axis="y", color ="blue")
ax2.tick_params(axis="y", color ="blue")
plt.show()

# %% [markdown]
# # Task 8, 9

# %%
mean=data['Price'].mean()
mode = data['Price'].mode()
median = data['Price'].median()
skew = data['Price'].skew(axis = 0)
print(f"mean : {mean} \n mode : {mode} \n median : {median} \n skew : {skew}")
# Out:
# mean : 281171.9015011236
#  mode : 0    460001.256
# dtype: float64
#  median : 249075.6568
#  skew : 1.0960149435317839

# %% [markdown]
# # Task10

# %% [markdown]
# Task 10: Calculate the covariance and correlation coefficient between Price and Area, no matter if the apartment is sold or not. Is the result in line with the scatter plot?
#
#
# Solution:
#
# Covariance	24147721.73
# Correlation	0.951087377
#
# Yes, the result is in line with the scatter plot. The two variables are greatly correlated.

# %%
covariance = data['Price'].cov(data['Area (ft.)'])
correlation = data['Price'].corr(data['Area (ft.)'])
plt.scatter(covariance,correlation, alpha = 1)
plt.show()
print(f'covariance = {covariance} \n correlation = {correlation}')
# Out:
# covariance = 24147721.72581887
#  correlation = 0.9510873774316205
